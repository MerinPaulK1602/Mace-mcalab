# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
train_data = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Titanic_Train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Titanic_Test.csv')

# %%
train_data.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
train_data1 = train_data.drop_duplicates(subset="Pclass")
train_data1
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 9                Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C
# 9      0     237736  30.0708   NaN        C

# %%
train_data2 = train_data.drop_duplicates(subset="Survived")
train_data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
train_data3 = train_data.drop_duplicates(subset="SibSp")
train_data3
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 0              1         0       3             Braund, Mr. Owen Harris
# 2              3         1       3              Heikkinen, Miss. Laina
# 7              8         0       3      Palsson, Master. Gosta Leonard
# 16            17         0       3                Rice, Master. Eugene
# 38            39         0       3  Vander Planke, Miss. Augusta Maria
# 59            60         0       3  Goodwin, Master. William Frederick
# 159          160         0       3          Sage, Master. Thomas Henry
#
#         Sex   Age  SibSp  Parch            Ticket    Fare Cabin Embarked
# 0      male  22.0      1      0         A/5 21171   7.250   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.925   NaN        S
# 7      male   2.0      3      1            349909  21.075   NaN        S
# 16     male   2.0      4      1            382652  29.125   NaN        Q
# ...

# %%
train_data4 = train_data.drop_duplicates(subset="Parch")
train_data4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 7              8         0       3
# 8              9         1       3
# 13            14         0       3
# 86            87         0       3
# 167          168         0       3
# 678          679         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 86                              Ford, Mr. William Neal    male  16.0      1
# 167    Skoog, Mrs. William (Anna Bernhardina Karlsson)  female  45.0      1
# 678            Goodwin, Mrs. Frederick (Augusta Tyler)  female  43.0      1
#
#      Parch      Ticket     Fare Cabin Embarked
# ...

# %%
train_data5 = train_data.drop_duplicates(subset="Embarked")
train_data5
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 5             6         0       3
# 61           62         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 5                                    Moran, Mr. James    male   NaN      0
# 61                                Icard, Miss. Amelie  female  38.0      0
#
#     Parch     Ticket     Fare Cabin Embarked
# 0       0  A/5 21171   7.2500   NaN        S
# 1       0   PC 17599  71.2833   C85        C
# 5       0     330877   8.4583   NaN        Q
# 61      0     113572  80.0000   B28      NaN

# %%
train_data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
a=train_data[['Age']].mean()

# %%
a
# Out:
# Age    29.699118
# dtype: float64

# %%
train_data.fillna(0, inplace=True)

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
train_data['Cabin']
# Out:
# 0         0
# 1       C85
# 2         0
# 3      C123
# 4         0
#        ...
# 886       0
# 887     B42
# 888       0
# 889    C148
# 890       0
# Name: Cabin, Length: 891, dtype: object

# %%
train_data['Embarked']
# Out:
# 0      S
# 1      C
# 2      S
# 3      S
# 4      S
#       ..
# 886    S
# 887    S
# 888    S
# 889    C
# 890    Q
# Name: Embarked, Length: 891, dtype: object

# %%
train_data.fillna(0, inplace=True)

# %%
train_data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %%
data = train_data.drop_duplicates(subset="Survived")
data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500     0        S
# 1      0   PC 17599  71.2833   C85        C

# %%
train_data['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn import preprocessing

# %%
label_encoder = preprocessing.LabelEncoder()
data["Sex"]=label_encoder.fit_transform(data['Sex'])
# Out:
# <ipython-input-207-53373e0b3886>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Sex"]=label_encoder.fit_transform(data['Sex'])

# %%
label_encoder = preprocessing.LabelEncoder()
data["Sex"]=label_encoder.fit_transform(data['Embarked'])
# Out:
# <ipython-input-208-76c1f4aad2f5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data["Sex"]=label_encoder.fit_transform(data['Embarked'])

# %%
data=train_data.drop(['PassengerId','Name','Ticket','Cabin'],axis='columns')

# %%
data.head()
# Out:
#    Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0         0       3    male  22.0      1      0   7.2500        S
# 1         1       1  female  38.0      1      0  71.2833        C
# 2         1       3  female  26.0      0      0   7.9250        S
# 3         1       1  female  35.0      1      0  53.1000        S
# 4         0       3    male  35.0      0      0   8.0500        S

# %%
label_encoder = preprocessing.LabelEncoder()
data["Sex"]=label_encoder.fit_transform(data['Sex'])

# %%
X = data.drop(['Survived'],axis=1)

# %%
X
# Out:
#      Pclass  Sex   Age     Fare
# 0         3    1  22.0   7.2500
# 1         1    0  38.0  71.2833
# 2         3    0  26.0   7.9250
# 3         1    0  35.0  53.1000
# 4         3    1  35.0   8.0500
# ..      ...  ...   ...      ...
# 886       2    1  27.0  13.0000
# 887       1    0  19.0  30.0000
# 888       3    0   0.0  23.4500
# 889       1    1  26.0  30.0000
# 890       3    1  32.0   7.7500
#
# [891 rows x 4 columns]

# %%
Y = data['Survived']

# %% [markdown]
# pclass,sex,age fair

# %%
Y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn import metrics

# %%
gnb=GaussianNB()

# %%
gnb.fit(X,Y)
# Out:
# GaussianNB()

# %%
test_data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
label_encoder = preprocessing.LabelEncoder()
test_data["Sex"]=label_encoder.fit_transform(test_data['Sex'])

# %%
test_data.fillna(0, inplace=True)

# %%
test_X=test_data.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns')

# %%
test_X
# Out:
#      Pclass  Sex   Age      Fare
# 0         3    1  34.5    7.8292
# 1         3    0  47.0    7.0000
# 2         2    1  62.0    9.6875
# 3         3    1  27.0    8.6625
# 4         3    0  22.0   12.2875
# ..      ...  ...   ...       ...
# 413       3    1   0.0    8.0500
# 414       1    0  39.0  108.9000
# 415       3    1  38.5    7.2500
# 416       3    1   0.0    8.0500
# 417       3    1   0.0   22.3583
#
# [418 rows x 4 columns]

# %%
y_pred=gnb.predict(test_X)

# %%
#submission file
submission = pd.DataFrame({'Pclass': test_data['Pclass'],
                            'Sex': test_data['Sex'],
                            'Age': test_data['Age'],
                            'Fare': test_data['Fare'],
                            'Survived': y_pred})

# %%
submission
# Out:
#      Pclass  Sex   Age      Fare  Survived
# 0         3    1  34.5    7.8292         0
# 1         3    0  47.0    7.0000         1
# 2         2    1  62.0    9.6875         0
# 3         3    1  27.0    8.6625         0
# 4         3    0  22.0   12.2875         1
# ..      ...  ...   ...       ...       ...
# 413       3    1   0.0    8.0500         0
# 414       1    0  39.0  108.9000         1
# 415       3    1  38.5    7.2500         0
# 416       3    1   0.0    8.0500         0
# 417       3    1   0.0   22.3583         0
#
# [418 rows x 5 columns]

# %%
print("model accuracy:", metrics.accuracy_score(testy.values, y_pred)*100)
