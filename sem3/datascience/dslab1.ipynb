# %%
import pandas as pd

# %%
data = {
    'Name':['Alice','Bob','Charlie','David','Emma','Gini'],
    'Age':[25, 30, 35, 28, 22, 38],
    'Salary' : [50000, 60000, 75000, 52000, 48000, 40000]
    }

df = pd.DataFrame(data)

# %%
print("first few rows")
print(df.head())
# Out:
# first few rows
#       Name  Age  Salary
# 0    Alice   25   50000
# 1      Bob   30   60000
# 2  Charlie   35   75000
# 3    David   28   52000
# 4     Emma   22   48000

# %%
print("last few rows")
print(df.tail())
# Out:
# last few rows
#       Name  Age  Salary
# 1      Bob   30   60000
# 2  Charlie   35   75000
# 3    David   28   52000
# 4     Emma   22   48000
# 5     Gini   38   40000

# %%
print("count of values")
print(df.count())
# Out:
# count of values
# Name      6
# Age       6
# Salary    6
# dtype: int64

# %%
df.count()
# Out:
# Name      6
# Age       6
# Salary    6
# dtype: int64

# %%
print("sum of values")
df.sum()
# Out:
# sum of values
# Name      AliceBobCharlieDavidEmmaGini
# Age                                178
# Salary                          325000
# dtype: object

# %%
print("mean of values")
df.mean()
# Out:
# mean of values
# <ipython-input-12-976b637ed088>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Age          29.666667
# Salary    54166.666667
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    6 non-null      object
#  1   Age     6 non-null      int64
#  2   Salary  6 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 272.0+ bytes

# %%
print("median of values")
df.median()
# Out:
# median of values
# <ipython-input-14-9181547ba0d3>:2: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Age          29.0
# Salary    51000.0
# dtype: float64

# %%
print("mode of values")
df.mode().iloc[0]
# Out:
# mode of values
# Name      Alice
# Age          22
# Salary    40000
# Name: 0, dtype: object

# %%
print("standard deviation of values")
df.std()
# Out:
# standard deviation of values
# <ipython-input-16-367f1db60650>:2: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Age           6.022181
# Salary    12073.386711
# dtype: float64

# %%
print("minimum value")
df.min()
# Out:
# minimum value
# Name      Alice
# Age          22
# Salary    40000
# dtype: object

# %%
print("maximum value")
df.max()
# Out:
# maximum value
# Name       Gini
# Age          38
# Salary    75000
# dtype: object

# %%
df[['Age']].max()
# Out:
# Age    38
# dtype: int64

# %%
df.Age.max()
# Out:
# 38

# %%
print("absolute value")
df[['Age', 'Salary']].abs()
# Out:
# absolute value
#    Age  Salary
# 0   25   50000
# 1   30   60000
# 2   35   75000
# 3   28   52000
# 4   22   48000
# 5   38   40000

# %%
print("product of values")
df[['Age', 'Salary']].prod()
# Out:
# product of values
# Age                 614460000
# Salary    2503565916420177920
# dtype: int64

# %%
df['Age'].prod()
# Out:
# 614460000

# %%
print("cumulative sum")
df[['Age', 'Salary']].cumsum()
# Out:
# cumulative sum
#    Age  Salary
# 0   25   50000
# 1   55  110000
# 2   90  185000
# 3  118  237000
# 4  140  285000
# 5  178  325000

# %%
print("cumulative product")
df[['Age', 'Salary']].cumprod()
# Out:
# cumulative product
#          Age               Salary
# 0         25                50000
# 1        750           3000000000
# 2      26250      225000000000000
# 3     735000 -6746744073709551616
# 4   16170000  7323419986410602496
# 5  614460000  2503565916420177920

# %%
print("statistics summary")
df.describe()
# Out:
# statistics summary
#              Age        Salary
# count   6.000000      6.000000
# mean   29.666667  54166.666667
# std     6.022181  12073.386711
# min    22.000000  40000.000000
# 25%    25.750000  48500.000000
# 50%    29.000000  51000.000000
# 75%    33.750000  58000.000000
# max    38.000000  75000.000000
