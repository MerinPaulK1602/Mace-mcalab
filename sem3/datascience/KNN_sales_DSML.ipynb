# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# google mounted

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# importing libraries

# %%
df = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Sales_Train.csv')

# %% [markdown]
# reading traing dataset

# %%
df.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %% [markdown]
# display first five instances

# %%
df.tail()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 8518         Snack Foods  214.5218            OUT013
# 8519        Baking Goods  108.1570            OUT045
# 8520  Health and Hygiene   85.1224            OUT035
# 8521         Snack Foods  103.1332            OUT018
# 8522         Soft Drinks   75.4670            OUT046
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 8518                       1987        High               Tier 3
# 8519                       2002         NaN               Tier 2
# ...

# %% [markdown]
# display last 5 instanmces

# %%
df.count()
# Out:
# Item_Identifier              8523
# Item_Weight                  7060
# Item_Fat_Content             8523
# Item_Visibility              8523
# Item_Type                    8523
# Item_MRP                     8523
# Outlet_Identifier            8523
# Outlet_Establishment_Year    8523
# Outlet_Size                  6113
# Outlet_Location_Type         8523
# Outlet_Type                  8523
# Item_Outlet_Sales            8523
# dtype: int64

# %% [markdown]
# counting value of each attribute

# %%
df.sum()
# Out:
# <ipython-input-10-7e5fdb616c56>:1: FutureWarning: The default value of numeric_only in DataFrame.sum is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.sum()
# Item_Identifier              FDA15DRC01FDN15FDX07NCD19FDP36FDO10FDP10FDH17F...
# Item_Weight                                                          90774.975
# Item_Fat_Content             Low FatRegularLow FatRegularLow FatRegularRegu...
# Item_Visibility                                                     563.643281
# Item_Type                    DairySoft DrinksMeatFruits and VegetablesHouse...
# Item_MRP                                                          1201681.4808
# Outlet_Identifier            OUT049OUT018OUT049OUT010OUT013OUT018OUT013OUT0...
# Outlet_Establishment_Year                                             17027521
# ...

# %% [markdown]
# finding sum of each attribute

# %%
df.mean()
# Out:
# <ipython-input-11-c61f0c8f89b5>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.mean()
# Item_Weight                    12.857645
# Item_Visibility                 0.066132
# Item_MRP                      140.992782
# Outlet_Establishment_Year    1997.831867
# Item_Outlet_Sales            2181.288914
# dtype: float64

# %% [markdown]
# find mean value of each attribute

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df.median()
# Out:
# <ipython-input-13-6d467abf240d>:1: FutureWarning: The default value of numeric_only in DataFrame.median is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.median()
# Item_Weight                    12.600000
# Item_Visibility                 0.053931
# Item_MRP                      143.012800
# Outlet_Establishment_Year    1999.000000
# Item_Outlet_Sales            1794.331000
# dtype: float64

# %% [markdown]
# median value of each numerical attribute

# %%
df.mode().iloc[0]
# Out:
# Item_Identifier                              FDG33
# Item_Weight                                  12.15
# Item_Fat_Content                           Low Fat
# Item_Visibility                                0.0
# Item_Type                    Fruits and Vegetables
# Item_MRP                                  172.0422
# Outlet_Identifier                           OUT027
# Outlet_Establishment_Year                   1985.0
# Outlet_Size                                 Medium
# Outlet_Location_Type                        Tier 3
# Outlet_Type                      Supermarket Type1
# Item_Outlet_Sales                          958.752
# Name: 0, dtype: object

# %%
df.std()
# Out:
# <ipython-input-15-ce97bb7eaef8>:1: FutureWarning: The default value of numeric_only in DataFrame.std is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.std()
# Item_Weight                     4.643456
# Item_Visibility                 0.051598
# Item_MRP                       62.275067
# Outlet_Establishment_Year       8.371760
# Item_Outlet_Sales            1706.499616
# dtype: float64

# %%
df.min()
# Out:
# <ipython-input-16-c3612c624a3f>:1: FutureWarning: The default value of numeric_only in DataFrame.min is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.min()
# Item_Identifier                      DRA12
# Item_Weight                          4.555
# Item_Fat_Content                        LF
# Item_Visibility                        0.0
# Item_Type                     Baking Goods
# Item_MRP                             31.29
# Outlet_Identifier                   OUT010
# Outlet_Establishment_Year             1985
# Outlet_Location_Type                Tier 1
# Outlet_Type                  Grocery Store
# Item_Outlet_Sales                    33.29
# dtype: object

# %% [markdown]
# minimum value of each attribute

# %%
df.max()
# Out:
# <ipython-input-17-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# Item_Identifier                          NCZ54
# Item_Weight                              21.35
# Item_Fat_Content                           reg
# Item_Visibility                       0.328391
# Item_Type                        Starchy Foods
# Item_MRP                              266.8884
# Outlet_Identifier                       OUT049
# Outlet_Establishment_Year                 2009
# Outlet_Location_Type                    Tier 3
# Outlet_Type                  Supermarket Type3
# Item_Outlet_Sales                   13086.9648
# dtype: object

# %% [markdown]
# maximum value of each attribute

# %%
df.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
df['Item_Visibility'].prod()
# Out:
# 0.0

# %%
df[['Item_Outlet_Sales']].max()
# Out:
# Item_Outlet_Sales    13086.9648
# dtype: float64

# %% [markdown]
# maximum outlet sales of item

# %%
df[['Item_Outlet_Sales']].min()
# Out:
# Item_Outlet_Sales    33.29
# dtype: float64

# %% [markdown]
# minimum outlet sales of item

# %%
df.shape
# Out:
# (8523, 12)

# %% [markdown]
# training dataset have 8523 instances and 12 columns

# %%
df.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %% [markdown]
# training dataset have null values on item weight and outlet size

# %%
data = df.drop_duplicates(subset = "Item_Outlet_Sales")
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8506           DRF37       17.250          Low Fat         0.084676
# 8507           FDN28        5.880          Regular         0.030242
# 8510           FDN58       13.800          Regular         0.056862
# 8517           FDF53       20.750              reg         0.083607
# 8518           FDF22        6.865          Low Fat         0.056783
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
data = df.drop_duplicates(subset = "Outlet_Type")
data
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 3           FDX07        19.20          Regular         0.000000
# 7           FDP10          NaN          Low Fat         0.127470
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 3  Fruits and Vegetables  182.0950            OUT010
# 7            Snack Foods  107.7622            OUT027
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# 3                       1998         NaN               Tier 3
# 7                       1985      Medium               Tier 3
#
#          Outlet_Type  Item_Outlet_Sales
# ...

# %%
plt.hist(df['Item_Outlet_Sales'], color="cyan", edgecolor="blue")
plt.show()

# %% [markdown]
# histogram visualization of outlet sales of item

# %%
sns.boxplot(x='Outlet_Type', y='Item_Outlet_Sales', data=df)
plt.show()

# %%
train_data = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Sales_Train.csv')
test_data = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Sales_Test.csv')

# %% [markdown]
# read testing and training dataset

# %%
#missing data
train_data.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
#handle missing values
train_data.fillna(0, inplace=True)
test_data.fillna(0, inplace=True)

# %%
train_data.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %%
#encode categorical data
train_data=pd.get_dummies(train_data,columns=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type'])
test_data=pd.get_dummies(test_data,columns=['Item_Fat_Content','Item_Type','Outlet_Size','Outlet_Location_Type','Outlet_Type'])

# %%
train_data.head()
# Out:
#   Item_Identifier  Item_Weight  Item_Visibility  Item_MRP Outlet_Identifier  \
# 0           FDA15         9.30         0.016047  249.8092            OUT049
# 1           DRC01         5.92         0.019278   48.2692            OUT018
# 2           FDN15        17.50         0.016760  141.6180            OUT049
# 3           FDX07        19.20         0.000000  182.0950            OUT010
# 4           NCD19         8.93         0.000000   53.8614            OUT013
#
#    Outlet_Establishment_Year  Item_Outlet_Sales  Item_Fat_Content_LF  \
# 0                       1999          3735.1380                    0
# 1                       2009           443.4228                    0
# 2                       1999          2097.2700                    0
# 3                       1998           732.3800                    0
# 4                       1987           994.7052                    0
#
#    Item_Fat_Content_Low Fat  Item_Fat_Content_Regular  ...  Outlet_Size_High  \
# ...

# %%
#split the train data to features and target
X=train_data.drop(['Item_Identifier','Outlet_Identifier','Item_Outlet_Sales'],axis=1)
Y=train_data['Item_Outlet_Sales']

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
#create the KNN model
knn=KNeighborsRegressor(n_neighbors=3)

# %%
#fitting
knn.fit(X, Y)
# Out:
# KNeighborsRegressor(n_neighbors=3)

# %%
# Use the model to make predictions on the test data
X_test = test_data.drop(['Item_Identifier', 'Outlet_Identifier'], axis=1)
test_predictions = knn.predict(X_test)

# %%
#submission file
submission = pd.DataFrame({'Item_Identifier': test_data['Item_Identifier'],
                            'Outlet_Identifier': test_data['Outlet_Identifier'],
                            'Item_Outlet_Sales': test_predictions})

# %%
submission.to_csv('/content/drive/MyDrive/dsml_lab_dataset/Sales_Sample_Submission.csv', index=False)

# %%
df = pd.read_csv('/content/drive/MyDrive/dsml_lab_dataset/Sales_Sample_Submission.csv')

# %%
print(df)
# Out:
#      Item_Identifier Outlet_Identifier  Item_Outlet_Sales
# 0              FDW58            OUT049        1716.210467
# 1              FDW14            OUT017        1446.117600
# 2              NCN55            OUT010        1778.573733
# 3              FDQ58            OUT017        2319.869133
# 4              FDY38            OUT027        4921.593600
# ...              ...               ...                ...
# 5676           FDB58            OUT046        1424.812000
# 5677           FDD47            OUT018        2741.098600
# 5678           NCO17            OUT045        1235.059000
# 5679           FDJ26            OUT017        3662.121933
# 5680           FDU37            OUT045        1658.729733
#
# [5681 rows x 3 columns]
